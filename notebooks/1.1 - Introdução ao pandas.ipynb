# %% [markdown]
# **Índice**<a id='toc0_'></a>
# - [Material de apoio](#toc1_1_)
#     - [Referências de apoio para uso do pandas ao longo do curso](#toc1_1_1_)
#   - [Sobre o Pandas](#toc1_2_)
# - [Caso 1](#toc2_)
#     - [Lendo arquivos](#toc2_1_1_)
#   - [Acessando informações básicas de um DataFrame](#toc2_2_)
#   - [Acessando dados em um DataFrame](#toc2_3_)
#     - [Acessando colunas](#toc2_3_1_)
#     - [Acessando linhas](#toc2_3_2_)
#     - [Acessando células](#toc2_3_3_)
#     - [Também é possível acessar ranges](#toc2_3_4_)
#     - [Indexação lógica](#toc2_3_5_)
#     - [Criando novas colunas](#toc2_3_6_)
#     - [Excluindo colunas](#toc2_3_7_)
#     - [Executando operações permanentes](#toc2_3_8_)
#   - [Retornando ao caso: encontrando casos onde há compra de cloroquina](#toc2_4_)
#     - [Tratando os dados](#toc2_4_1_)
#     - [Conclusão](#toc2_4_2_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=3
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ## <a id='toc1_1_'></a>[Material de apoio](#toc0_)
#
#
#
# ### <a id='toc1_1_1_'></a>[Referências de apoio para uso do pandas ao longo do curso](#toc0_)
#
#
# Esse link contém uma tabela que serve de referência para várias das funções do pandas: [https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf). As explicações são dadas de forma um pouco técnica, mas isso não é um problema se já conhecemos as operações.
#
# [Essa série de vídeos contém explicações sobre o funcionamento do pandas: https://www.youtube.com/watch?v=7myBWiNwZBc](https://www.youtube.com/watch?v=7myBWiNwZBc&ab_channel=UniversidadedosDados)
#
# #### Query
#
# **Importante: [esse vídeo explica o funcionamento do método `query` que usamos para filtrar dados: https://www.youtube.com/watch?v=c1Xz9wXQSGM](https://www.youtube.com/watch?v=c1Xz9wXQSGM)**.
#
# [O artigo a seguir também contém algumas explicações e dicas de como usar o `query`: <br> https://towardsdatascience.com/10-examples-that-will-make-you-use-pandas-query-function-more-often-a8fb3e9361cb](https://towardsdatascience.com/10-examples-that-will-make-you-use-pandas-query-function-more-often-a8fb3e9361cb)
#
# [Capítulo sobre sumarização e tratamento de dados com o pandas: https://statsthinking21.github.io/statsthinking21-python/02-SummarizingData.html](https://statsthinking21.github.io/statsthinking21-python/02-SummarizingData.html)
#
# ## <a id='toc1_2_'></a>[Sobre o Pandas](#toc0_)
#
# Para realizar grandes coisas, precisamos subir sobre os ombros de gigantes. A comunidade Python é incrível e já desenvolveu muitas ferramentas que foram disponibilizadas gratuitamente para os usuários da plataforma. Não há necessidade de reinventar a roda.
#
# Uma dessas ferramentas é o pacote `Pandas`, que vamos usar para ler e trabalhar com dados estruturados.

# %%
import pandas

# %% [markdown]
# Essa linha importa o pacote `Pandas` e todas as funções e métodos que estão contidos nele. Usando a notação acima, toda vez que quisermos usar qualquer função do Pandas, como `read_csv`, precisamos escrever o nome inteiro do pacote, usando `pandas.read_csv`. Por conta da inconveniência da digitação extra, costumamos importar a maior parte dos pacotes usando certas abreviações ou "aliases" com a seguinte notação:

# %%
import pandas as pd

# %% [markdown]
# No caso do pacote `pandas` a abreviação canônica é `pd`. Assim, sempre utilizaremos essa forma de importar a biblioteca.
#
# Vários outros pacotes possuem abreviações similares. É fácil encontrar na internet exemplos de importação canônica para cada um deles.
#
# # <a id='toc2_'></a>[Caso 1](#toc0_)
#
# Recentemente, os dados do [portal de compras do Governo Federal](http://compras.dados.gov.br/docs/home.html) foram destaque por conta do [elevado valor gasto com leite condensado nos anos de 2019 e 2020](https://www1.folha.uol.com.br/colunas/monicabergamo/2021/01/psol-pede-que-pgr-investigue-gasto-federal-de-r-18-bilhao-com-alimentos-e-bebidas.shtml). Outro assunto polêmico de 2020 envolveu o uso da Cloroquina contra o COVID-19 ([apontado como inefetivo pela comunidade científica](https://noticias.uol.com.br/colunas/jamil-chade/2020/10/16/oms-estudo-global-revela-que-remdesivir-e-cloroquina-nao-funcionam.htm)). Quanto será que o governo gastou com Cloroquina ao longo de 2020? Preparei um arquivo CSV com todas as compras sem licitação do Governo Federal em 2020 pra iniciar nossa experimentação com o Pandas.
#
# ##Algumas funcionalidades do pandas.
#
# ### <a id='toc2_1_1_'></a>[Lendo arquivos](#toc0_)
#
# Já falamos a respeito da função `read_csv`. Ela é responsável por fazer exatamente o que seu nome sugere: ler arquivos ".csv". Mas pra que queremos ler arquivos ".csv"?
#
# O `pandas` é uma biblioteca que introduz no Python um tipo de objeto especialmente desenhado para lidar com **tabelas**: o `DataFrame`.
#
# *Arquivos .csv* (comma separated values) são o formato aberto mais universal para a leitura de tabelas.
#
#   Ao longo do curso, vamos ver como é possível usar o `pandas` para ler arquvios tirados de uma API, como podemos usar a biblioteca pra ler arquivos do Excel, e até mesmo para extrair as tabelas contidas em uma página da internet.
#
# Uma característica interessante do Pandas é que *ele consegue ler arquivos a partir da URL*. Se você tem um link que faz o download de um arquivo csv, pode usar esse link para carregar esse arquivo diretamente para o Pandas.

# %%
compras_2020 = pd.read_csv("https://bit.ly/3amlUZK")

# %% [markdown]
# O arquivo foi carregado como um novo tipo de objeto no Python: um `DataFrame` do `pandas`.

# %%
type(compras_2020)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# A biblioteca `pandas` é muito bem estabelecida e recebe muito apoio da comunidade de programadores de python, assim muito do que precisamos fazer já está pronto de alguma forma. Também podemos carregar outros formatos de dado como arquivos excel com a função `read_excel` e até carregar dados de sites seja baixando o arquivo, perceba como estamos passando um link para carregar o csv, ou do código HTML de uma página - há um arquivo específico sobre esse assunto.
#
# ## <a id='toc2_2_'></a>[Acessando informações básicas de um DataFrame](#toc0_)
#
# Assim como *listas e dicionários* possuíam certos métodos que nos permitiam fazer coisas interessantes com essas estruturas de dados (por exemplo, usando `.insert()` e `.pop()` em listas), os `DataFrames` também possuem vários métodos desenhados para facilitar o trabalho do cientista de dados.
#
# Um bom primeiro passo é obter um panorama das informações que possuímos, algo que pode ser feito usando os métodos do `pandas` `.head()` e `.tail()`.

# %%
compras_2020.head()
# Out:
#                                                Orgão  \
# 0                      52111: COMANDO DA AERONAUTICA
# 1  29208: COMPANHIA DE PESQUISA DE RECURSOS MINERAIS
# 2                      25000: MINISTERIO DA ECONOMIA
# 3  22202: EMPRESA BRASILEIRA DE PESQUISA AGROPECU...
# 4         37202: INSTITUTO NACIONAL DO SEGURO SOCIAL
#
#                                                 UASG  \
# 0         120641: GRUPAMENTO DE APOIO DE PORTO VELHO
# 1  495500: COMPANHIA DE PESQUISA DE RECURSOS MINE...
# 2     170198: DELEGACIA DA REC.FEDERAL EM GOIANIA/GO
# 3                               135020: EMBRAPA/CTAA
# 4             511359: GERÊNCIA EXECUTIVA CAMPINAS/SP
#
#   Código da modalidade da compra  Descrição Lei  Número Inciso  \
# 0                    6: Dispensa            NaN              2
# 1                    6: Dispensa            NaN              2
# 2                    6: Dispensa            NaN              2
# 3                    6: Dispensa            NaN              4
# 4                    6: Dispensa            NaN              2
#
#      Número processo  Quantidade item Valor total da compra  Número da compra  \
# 0  67206014598202031              NaN             R$ 313.00               NaN
# 1  48048.000613/2020              NaN          R$ 20,716.00               NaN
# 2  10120759636201977              NaN          R$ 14,245.00               NaN
# 3  21152.000208/2020              NaN         R$ 137,104.00               NaN
# 4  35014040275202063              NaN           R$ 8,760.00               NaN
#
#                           Descrição objeto licitação  \
# 0  Objeto: Contratação do serviço de prestação de...
# 1  Objeto: Aquisição de dispenser para álcool gel...
# 2  Objeto: Contratação de serviços de confecção d...
# 3  Objeto: Contratação de Prestação de Serviços d...
# 4  Objeto: Contratação de Companhia de Seguros pa...
#
#                              Descrição justificativa  \
# 0  Justificativa: Despesa de pequeno vulto, confo...
# 1  Justificativa: Aquisição de produtos e/ou serv...
# 2  Justificativa: Pequeno valor.                 ...
# 3  Justificativa: Contratação temporária, em cará...
# 4  Justificativa: Procedimento simplificado e de ...
#
#   Data de reconhecimento da compra sem licitação  \
# 0                                     06/03/2020
# 1                                     29/05/2020
# 2                                     27/12/2019
# 3                                     27/02/2020
# 4                                     14/04/2020
#
#   Data da ratificação da compra sem licitação  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                  27/02/2020
# 4                                         NaN
#
#   Data da publicação da compra sem licitação  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                 28/02/2020
# 4                                        NaN
#
#                                          Itens > uri
# 0  /compraSemLicitacao/id/item_slicitacao/1206410...
# 1  /compraSemLicitacao/id/item_slicitacao/4955000...
# 2  /compraSemLicitacao/id/item_slicitacao/1701980...
# 3  /compraSemLicitacao/id/item_slicitacao/1350200...
# 4  /compraSemLicitacao/id/item_slicitacao/5113590...

# %%
compras_2020.shape
# Out:
# (96005, 15)

# %% [markdown]
# A tabela compras_2020 tem mais de 90 mil linhas! Por isso, pode não ser uma boa ideia imprimir todas as linhas de uma única vez. O tamanho dessa tabela também justifica a preferência pelo Python: tabelas desse tamanho começam a se comportar de maneira bastante lenta em plataformas como o Excel (inclusive, quando as tabelas são realmente muito grandes, o Excel sequer consegue abrir!).
#
# A função info oferece informações importantes: o tipo dos dados armazenados em cada coluna, quantos valores estão preenchidos com valores não nulos

# %%
compras_2020.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## <a id='toc2_3_'></a>[Acessando dados em um DataFrame](#toc0_)
#
# Um `DataFrame` é uma estrutura de dados (também um tipo de variável) que representa uma tabela. Tabelas são compostas por linhas e colunas.
#
# Cada interseção entre linhas e colunas é chamada de uma **célula**.
#
# Algumas vezes, queremos acessar a informação constante de uma linha. Outras vezes, estamos interessados em conseguir as informações de uma coluna inteira. Ainda outras vezes, queremos apenas o valor armazenado em uma célula.
#
# ### <a id='toc2_3_1_'></a>[Acessando colunas](#toc0_)

# %%
#imprime o nome de todas as colunas
compras_2020.columns
# Out:
# Index(['Orgão', 'UASG', 'Código da modalidade da compra', 'Descrição Lei',
#        'Número Inciso', 'Número processo', 'Quantidade item',
#        'Valor total da compra', 'Número da compra',
#        'Descrição objeto licitação', 'Descrição justificativa',
#        'Data de reconhecimento da compra sem licitação',
#        'Data da ratificação da compra sem licitação',
#        'Data da publicação da compra sem licitação', 'Itens > uri'],
#       dtype='object')

# %% [markdown]
# Podemos acessar as colunas como se fosse uma lista. Veja que o resultado é muito parecido com de uma lista, mas indicando que é um **Índice (index)**

# %%
cols_compras = compras_2020.columns

cols_compras[1]
# Out:
# 'UASG'

# %%
compras_2020["Orgão"] # notem como é similar a um dicionário
# Out:
# 0                            52111: COMANDO DA AERONAUTICA
# 1        29208: COMPANHIA DE PESQUISA DE RECURSOS MINERAIS
# 2                            25000: MINISTERIO DA ECONOMIA
# 3        22202: EMPRESA BRASILEIRA DE PESQUISA AGROPECU...
# 4               37202: INSTITUTO NACIONAL DO SEGURO SOCIAL
#                                ...
# 96000             26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96001             26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96002             26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96003             26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96004                            52131: COMANDO DA MARINHA
# Name: Orgão, Length: 96005, dtype: object

# %%
compras_2020["Descrição objeto licitação"]
# Out:
# 0        Objeto: Contratação do serviço de prestação de...
# 1        Objeto: Aquisição de dispenser para álcool gel...
# 2        Objeto: Contratação de serviços de confecção d...
# 3        Objeto: Contratação de Prestação de Serviços d...
# 4        Objeto: Contratação de Companhia de Seguros pa...
#                                ...
# 96000    Objeto: Pagamento de Inscrição em Evento.     ...
# 96001    Objeto: Pagamento de Inscrição em Evento.     ...
# 96002    Objeto: Publicação do artigo científico intitu...
# 96003    Objeto: Despesa bancária com contratação cambi...
# 96004    Objeto: Serviço de telefonia                  ...
# Name: Descrição objeto licitação, Length: 96005, dtype: object

# %% [markdown]
# ### <a id='toc2_3_2_'></a>[Acessando linhas](#toc0_)

# %%
compras_2020.iloc[1]
# Out:
# Orgão                                             29208: COMPANHIA DE PESQUISA DE RECURSOS MINERAIS
# UASG                                              495500: COMPANHIA DE PESQUISA DE RECURSOS MINE...
# Código da modalidade da compra                                                          6: Dispensa
# Descrição Lei                                                                                   NaN
# Número Inciso                                                                                     2
# Número processo                                                                   48048.000613/2020
# Quantidade item                                                                                 NaN
# Valor total da compra                                                                  R$ 20,716.00
# Número da compra                                                                                NaN
# Descrição objeto licitação                        Objeto: Aquisição de dispenser para álcool gel...
# Descrição justificativa                           Justificativa: Aquisição de produtos e/ou serv...
# Data de reconhecimento da compra sem licitação                                           29/05/2020
# Data da ratificação da compra sem licitação                                                     NaN
# Data da publicação da compra sem licitação                                                      NaN
# Itens > uri                                       /compraSemLicitacao/id/item_slicitacao/4955000...
# Name: 1, dtype: object

# %% [markdown]
# Tanto uma linhas quanto uma coluna são do tipo `Series`, e os valores individuais podem ser acessados como por um *dicionário* usando a chave do valor desejado.

# %%
linha2 = compras_2020.iloc[1]

print(type(linha2))
# Out:
# <class 'pandas.core.series.Series'>

# %%
linha2["Valor total da compra"]
# Out:
# 'R$ 20,716.00'

# %% [markdown]
# `DataFrames`representam tabelas, e são compostos por diversas `Series`, que se assemelham a uma lista ordenada de valores contendo uma chave. Ao acessar uma linha ou coluna de uma variável DataFrame o `Pandas`gera uma variável do tipo `Series`. Mais a frente veremos que essas variáveis tem uma série de métodos, que utilizaremos para fazer operações em toda uma coluna (exemplo, somar ou cálcular a média).
#
# ### <a id='toc2_3_3_'></a>[Acessando células](#toc0_)
#
# Podemos combinar a forma de acessar linhas e colunas com a sintaxe `.iloc[indice]['nome_da_coluna']`:

# %%
compras_2020['Orgão'].iloc[1]
# Out:
# '29208: COMPANHIA DE PESQUISA DE RECURSOS MINERAIS'

# %% [markdown]
# Podemos obter o mesmo resultado alterando a ordem. Nesse caso, primeiro acessamos a coluna e depois a linha, chegando na mesma célula.

# %%
compras_2020.iloc[1]['Orgão']
# Out:
# '29208: COMPANHIA DE PESQUISA DE RECURSOS MINERAIS'

# %% [markdown]
# ### <a id='toc2_3_4_'></a>[Também é possível acessar ranges](#toc0_)
#
# A sintaxe para isso é distinta para linhas e para colunas.
#
# Para **linhas** usamos a indexação **junto ao iloc**, como para selecionar elementos de uma lista.
#
# Já para acessar **colunas**, passamos uma **lista de valores dentro dos colchetes que seleciona a coluna**. Observe que são abertos e fechados 2 colchetes.

# %%
compras_2020.iloc[0:24]['Orgão']
# Out:
# 0                         52111: COMANDO DA AERONAUTICA
# 1     29208: COMPANHIA DE PESQUISA DE RECURSOS MINERAIS
# 2                         25000: MINISTERIO DA ECONOMIA
# 3     22202: EMPRESA BRASILEIRA DE PESQUISA AGROPECU...
# 4            37202: INSTITUTO NACIONAL DO SEGURO SOCIAL
# 5     20701: INST.BRAS.DO MEIO AMB.E DOS REC.NAT.REN...
# 6                            52121: COMANDO DO EXERCITO
# 7                         25000: MINISTERIO DA ECONOMIA
# 8                            52121: COMANDO DO EXERCITO
# 9         26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 10    26420: INST.FED.DE EDUC.,CIENC. E TEC.FARROUPILHA
# 11           38701: CONSELHO REGIONAL DE FARMÁCIA DE PE
# 12                             14000: JUSTICA ELEITORAL
# 13                             94520: ESTADO DA PARAIBA
# 14                           52121: COMANDO DO EXERCITO
# 15        26405: INST.FED.DE EDUC.,CIENC.E TEC.DO CEARÁ
# 16                            52131: COMANDO DA MARINHA
# 17    26420: INST.FED.DE EDUC.,CIENC. E TEC.FARROUPILHA
# 18                 32396: AGENCIA NACIONAL DE MINERAÇÃO
# 19                           52121: COMANDO DO EXERCITO
# 20       26407: INST.FED.DE EDUC.,CIENCIA E TEC. GOIANO
# 21    26410: INST.FED.DE EDUC., CIENC.E TEC.DO NORTE...
# 22    39252: DEPTO. NAC. DE INFRA-ESTRUTURA DE TRANS...
# 23                           52121: COMANDO DO EXERCITO
# Name: Orgão, dtype: object

# %%
compras_2020.iloc[0:24][['Orgão', 'Descrição justificativa']]
# Out:
#                                                 Orgão  \
# 0                       52111: COMANDO DA AERONAUTICA
# 1   29208: COMPANHIA DE PESQUISA DE RECURSOS MINERAIS
# 2                       25000: MINISTERIO DA ECONOMIA
# 3   22202: EMPRESA BRASILEIRA DE PESQUISA AGROPECU...
# 4          37202: INSTITUTO NACIONAL DO SEGURO SOCIAL
# 5   20701: INST.BRAS.DO MEIO AMB.E DOS REC.NAT.REN...
# 6                          52121: COMANDO DO EXERCITO
# 7                       25000: MINISTERIO DA ECONOMIA
# 8                          52121: COMANDO DO EXERCITO
# 9       26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 10  26420: INST.FED.DE EDUC.,CIENC. E TEC.FARROUPILHA
# 11         38701: CONSELHO REGIONAL DE FARMÁCIA DE PE
# 12                           14000: JUSTICA ELEITORAL
# 13                           94520: ESTADO DA PARAIBA
# 14                         52121: COMANDO DO EXERCITO
# 15      26405: INST.FED.DE EDUC.,CIENC.E TEC.DO CEARÁ
# 16                          52131: COMANDO DA MARINHA
# 17  26420: INST.FED.DE EDUC.,CIENC. E TEC.FARROUPILHA
# 18               32396: AGENCIA NACIONAL DE MINERAÇÃO
# 19                         52121: COMANDO DO EXERCITO
# 20     26407: INST.FED.DE EDUC.,CIENCIA E TEC. GOIANO
# 21  26410: INST.FED.DE EDUC., CIENC.E TEC.DO NORTE...
# 22  39252: DEPTO. NAC. DE INFRA-ESTRUTURA DE TRANS...
# 23                         52121: COMANDO DO EXERCITO
#
#                               Descrição justificativa
# 0   Justificativa: Despesa de pequeno vulto, confo...
# 1   Justificativa: Aquisição de produtos e/ou serv...
# 2   Justificativa: Pequeno valor.                 ...
# 3   Justificativa: Contratação temporária, em cará...
# 4   Justificativa: Procedimento simplificado e de ...
# 5   Justificativa: Art. 24º, Inciso II da Lei nº 8...
# 6   Justificativa: Destina-se ao serviço de fornec...
# 7   Justificativa: Para atender as necessidades de...
# 8   Justificativa: Art. 25º, Inciso I da Lei nº 8....
# 9   Justificativa: Aquisição urgente de mangotes p...
# 10  Justificativa: Para a contratação de serviços ...
# 11  Justificativa: Aquisição de produtos e/ou serv...
# 12  Justificativa: Aquisição de produtos e/ou serv...
# 13  Justificativa: Aquisição de produtos e/ou serv...
# 14  Justificativa: Pagamento de seguro obrigatório...
# 15  Justificativa: Inciso II, do art. 25 da Lei nº...
# 16  Justificativa: Devido ao baixo valor da aquisi...
# 17  Justificativa: Lei 8666/93                    ...
# 18  Justificativa: Para atender às necessidades de...
# 19  Justificativa: Valor da despesa inferior ao li...
# 20  Justificativa: Contratação prevista no Art. 25...
# 21  Justificativa: Inviabilidade de competição, o ...
# 22  Justificativa: Valor enquadra-se no limite do ...
# 23  Justificativa: Credenciamento estará aberto pa...

# %% [markdown]
# ### <a id='toc2_3_5_'></a>[Indexação lógica](#toc0_)
#
# Com mais frequência, não queremos uma parte arbitrária do `DataFrame`, mas sim o subconjunto do `DataFrame` que satisfaz alguma condição. Por exemplo, podemos querer a relação de todas as compras feitas sem licitação pela UFRJ.
#
# Acima, podemos ver que a UFRJ é identificada na coluna Orgão pela string "26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO". Com essa informação, podemos pedir para que o `DataFrame` encontre apenas as linhas que possuem "26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO" no campo Orgão. Existem algumas maneiras de fazer isso. A mais simples delas envolve o método `.query()`.
#
# Podemos perceber nos exemplos abaixo que usamos uma sintaxe semelhante à de condicionais para definir a condição que as linhas que irão permanecer devem cumprir, mas podemos nos referir ao nome da coluna livremente dentro da *string* que delimita o query.

# %%
compras_2020.query("Orgão == '26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO'")
# Out:
#                                                Orgão  \
# 9      26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 26     26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 94     26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 147    26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 280    26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# ...                                              ...
# 95357  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 95360  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 95807  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 95836  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 95990  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
#
#                                                     UASG  \
# 9               153147: INSTITUTO DE GINECOLOGIA DA UFRJ
# 26            153131: MEC-FACULDADE DE EDUCACAO DA UF/RJ
# 94     153127: DECANATO DO CENTRO DE LETRAS E ARTES D...
# 147                158222: ESCOLA DE COMUNICAÇÃO DA UFRJ
# 280        158223: FACULDADE NACIONAL DE DIREITO DA UFRJ
# ...                                                  ...
# 95357  153150: INSTITUTO PUERIC. PED MAT. GESTEIRA DA...
# 95360  153150: INSTITUTO PUERIC. PED MAT. GESTEIRA DA...
# 95807  153150: INSTITUTO PUERIC. PED MAT. GESTEIRA DA...
# 95836  153150: INSTITUTO PUERIC. PED MAT. GESTEIRA DA...
# 95990  153150: INSTITUTO PUERIC. PED MAT. GESTEIRA DA...
#
#       Código da modalidade da compra  Descrição Lei  Número Inciso  \
# 9                        6: Dispensa            NaN              2
# 26                       6: Dispensa            NaN              0
# 94                       6: Dispensa            NaN              2
# 147                      6: Dispensa            NaN              2
# 280                      6: Dispensa            NaN              1
# ...                              ...            ...            ...
# 95357             7: Inexigibilidade            NaN              1
# 95360                    6: Dispensa            NaN              4
# 95807                    6: Dispensa            NaN              4
# 95836                    6: Dispensa            NaN              2
# 95990                    6: Dispensa            NaN              4
#
#          Número processo  Quantidade item Valor total da compra  \
# 9      23079000743202023              NaN           R$ 2,800.00
# 26     004290/2020-12                 NaN           R$ 2,396.00
# 94     003550/2020-24                 NaN           R$ 2,570.00
# 147    23079005165202011              NaN           R$ 3,000.00
# 280    23079004841202030              NaN           R$ 5,061.00
# ...                  ...              ...                   ...
# 95357  23079054034201509              NaN          R$ 70,683.00
# 95360  23079004452202012              NaN          R$ 71,223.00
# 95807  23079044146201977              NaN          R$ 86,600.00
# 95836  23079004450202015              NaN             R$ 650.00
# 95990  23079025601201935              NaN           R$ 9,884.00
#
#        Número da compra                         Descrição objeto licitação  \
# 9                   NaN  Objeto: Aquisição de mangotes                 ...
# 26                  NaN  Objeto: Aquisição de material de limpeza e pro...
# 94                  NaN  Objeto: Aquisição de material de elétrico para...
# 147                 NaN  Objeto: Retirada dos ventiladores com defeito;...
# 280                 NaN  Objeto: Reforma Recuperação de espaços paredes...
# ...                 ...                                                ...
# 95357               NaN  Objeto: Serviço de manutenção do aparelho BDFA...
# 95360               NaN  Objeto: Pagamento de Serviço de tratamento nef...
# 95807               NaN  Objeto: De Serviço de Manutenção do Sistema de...
# 95836               NaN  Objeto: Aquisição de serviço de exame de eletr...
# 95990               NaN  Objeto: De Serviço de Esterilização em Óxido d...
#
#                                  Descrição justificativa  \
# 9      Justificativa: Aquisição urgente de mangotes p...
# 26     Justificativa: Abaixo do valor exigido por lei...
# 94     Justificativa: Valor abaixo do limite permitid...
# 147    Justificativa: Valor dentro do limite de Dispe...
# 280    Justificativa: Abaixo do valor para licitar   ...
# ...                                                  ...
# 95357  Justificativa: Art. 25, I da Lei 8.666/93 (Ine...
# 95360  Justificativa: Art. 24, IV da Lei 8.666/93.   ...
# 95807  Justificativa: Art. 24, IV da Lei 8.666/93 (aq...
# 95836  Justificativa: Valor inferior ao exigido por l...
# 95990  Justificativa: Art. 24, IV da Lei 8.666/93 (Aq...
#
#       Data de reconhecimento da compra sem licitação  \
# 9                                         12/02/2020
# 26                                        28/04/2020
# 94                                        09/03/2020
# 147                                       08/06/2020
# 280                                       11/05/2020
# ...                                              ...
# 95357                                     02/03/2020
# 95360                                     11/11/2020
# 95807                                     09/04/2020
# 95836                                     30/09/2020
# 95990                                     03/03/2020
#
#       Data da ratificação da compra sem licitação  \
# 9                                             NaN
# 26                                            NaN
# 94                                            NaN
# 147                                           NaN
# 280                                           NaN
# ...                                           ...
# 95357                                  02/03/2020
# 95360                                  11/11/2020
# 95807                                  09/04/2020
# 95836                                         NaN
# 95990                                  03/03/2020
#
#       Data da publicação da compra sem licitação  \
# 9                                            NaN
# 26                                           NaN
# 94                                           NaN
# 147                                          NaN
# 280                                          NaN
# ...                                          ...
# 95357                                 03/03/2020
# 95360                                 12/11/2020
# 95807                                 13/04/2020
# 95836                                        NaN
# 95990                                 04/03/2020
#
#                                              Itens > uri
# 9      /compraSemLicitacao/id/item_slicitacao/1531470...
# 26     /compraSemLicitacao/id/item_slicitacao/1531310...
# 94     /compraSemLicitacao/id/item_slicitacao/1531270...
# 147    /compraSemLicitacao/id/item_slicitacao/1582220...
# 280    /compraSemLicitacao/id/item_slicitacao/1582230...
# ...                                                  ...
# 95357  /compraSemLicitacao/id/item_slicitacao/1531500...
# 95360  /compraSemLicitacao/id/item_slicitacao/1531500...
# 95807  /compraSemLicitacao/id/item_slicitacao/1531500...
# 95836  /compraSemLicitacao/id/item_slicitacao/1531500...
# 95990  /compraSemLicitacao/id/item_slicitacao/1531500...
#
# [1753 rows x 15 columns]

# %% [markdown]
# Podemos replicar o mesmo caminho para encontrar todas as despesas da FND, usando agora a coluna "UASG".

# %%
compras_2020.query("UASG == '158223: FACULDADE NACIONAL DE DIREITO DA UFRJ'")
# Out:
#                                                Orgão  \
# 280    26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 8300   26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 11632  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 13320  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 15770  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 16784  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 17197  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 19359  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 20033  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 20928  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 21948  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 22962  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
# 24012  26245: UNIVERSIDADE FEDERAL DO RIO DE JANEIRO
#
#                                                 UASG  \
# 280    158223: FACULDADE NACIONAL DE DIREITO DA UFRJ
# 8300   158223: FACULDADE NACIONAL DE DIREITO DA UFRJ
# 11632  158223: FACULDADE NACIONAL DE DIREITO DA UFRJ
# 13320  158223: FACULDADE NACIONAL DE DIREITO DA UFRJ
# 15770  158223: FACULDADE NACIONAL DE DIREITO DA UFRJ
# 16784  158223: FACULDADE NACIONAL DE DIREITO DA UFRJ
# 17197  158223: FACULDADE NACIONAL DE DIREITO DA UFRJ
# 19359  158223: FACULDADE NACIONAL DE DIREITO DA UFRJ
# 20033  158223: FACULDADE NACIONAL DE DIREITO DA UFRJ
# 20928  158223: FACULDADE NACIONAL DE DIREITO DA UFRJ
# 21948  158223: FACULDADE NACIONAL DE DIREITO DA UFRJ
# 22962  158223: FACULDADE NACIONAL DE DIREITO DA UFRJ
# 24012  158223: FACULDADE NACIONAL DE DIREITO DA UFRJ
#
#       Código da modalidade da compra  Descrição Lei  Número Inciso  \
# 280                      6: Dispensa            NaN              1
# 8300                     6: Dispensa            NaN              1
# 11632                    6: Dispensa            NaN              2
# 13320             7: Inexigibilidade            NaN              2
# 15770                    6: Dispensa            NaN              1
# 16784                    6: Dispensa            NaN              2
# 17197                    6: Dispensa            NaN              2
# 19359                    6: Dispensa            NaN              2
# 20033                    6: Dispensa            NaN              2
# 20928                    6: Dispensa            NaN              2
# 21948                    6: Dispensa            NaN              2
# 22962                    6: Dispensa            NaN              2
# 24012                    6: Dispensa            NaN              2
#
#          Número processo  Quantidade item Valor total da compra  \
# 280    23079004841202030              NaN           R$ 5,061.00
# 8300   23079216019202010              NaN             R$ 980.00
# 11632  23079216237202054              NaN          R$ 11,370.00
# 13320  23079006848202096              NaN          R$ 18,000.00
# 15770  23079215840202019              NaN          R$ 63,049.00
# 16784  23079210237202041              NaN           R$ 3,960.00
# 17197  23079213978202083              NaN          R$ 10,160.00
# 19359  23079219758202063              NaN           R$ 1,050.00
# 20033  23079218808202095              NaN           R$ 7,280.00
# 20928  23079219687202007              NaN           R$ 7,332.00
# 21948  23079216237202054              NaN           R$ 9,500.00
# 22962  23079210958202051              NaN          R$ 21,110.00
# 24012  23079.214178/2020              NaN          R$ 28,414.00
#
#        Número da compra                         Descrição objeto licitação  \
# 280                 NaN  Objeto: Reforma Recuperação de espaços paredes...
# 8300                NaN  Objeto: Contratação de serviço de descupinizaç...
# 11632               NaN  Objeto: Aquisição de patrimônio - Compra de 11...
# 13320               NaN  Objeto: Contratação de Empresa especializada e...
# 15770               NaN  Objeto: Contratação emergencial de empresa de ...
# 16784               NaN  Objeto: Contratação de empresa especializada p...
# 17197               NaN  Objeto: Contratação de serviço de limpeza e ma...
# 19359               NaN  Objeto: Objeto a aquisição de fonte de aliment...
# 20033               NaN  Objeto: Aquisição de  material permanente Note...
# 20928               NaN  Objeto: Aquisição de materiais e insumos para ...
# 21948               NaN  Objeto: Aquisição de 2 aparelhos de ar condici...
# 22962               NaN  Objeto: Contratação de serviço de Manutenção d...
# 24012               NaN  Objeto: Contratação de empresa especializada s...
#
#                                  Descrição justificativa  \
# 280    Justificativa: Abaixo do valor para licitar   ...
# 8300   Justificativa: Aaixo                          ...
# 11632  Justificativa: Aquisição de produtos e/ou serv...
# 13320  Justificativa: Inexigibilidade                ...
# 15770  Justificativa: Abaixo do valor para licitação ...
# 16784  Justificativa: Abaixo do valor para licitação ...
# 17197  Justificativa: Abaixo do valor para licitação ...
# 19359  Justificativa: Aquisição de produtos e/ou serv...
# 20033  Justificativa: Aquisição de produtos e/ou serv...
# 20928  Justificativa: Aquisição de produtos e/ou serv...
# 21948  Justificativa: Aquisição de produtos e/ou serv...
# 22962  Justificativa: Abaixo do valor para licitação ...
# 24012  Justificativa: Valor abaixo para licitação    ...
#
#       Data de reconhecimento da compra sem licitação  \
# 280                                       11/05/2020
# 8300                                      24/09/2020
# 11632                                     26/10/2020
# 13320                                     05/11/2020
# 15770                                     30/10/2020
# 16784                                     30/10/2020
# 17197                                     09/11/2020
# 19359                                     09/11/2020
# 20033                                     09/11/2020
# 20928                                     17/11/2020
# 21948                                     17/11/2020
# 22962                                     19/11/2020
# 24012                                     25/11/2020
#
#       Data da ratificação da compra sem licitação  \
# 280                                           NaN
# 8300                                          NaN
# 11632                                         NaN
# 13320                                         NaN
# 15770                                         NaN
# 16784                                         NaN
# 17197                                         NaN
# 19359                                         NaN
# 20033                                         NaN
# 20928                                         NaN
# 21948                                         NaN
# 22962                                         NaN
# 24012                                         NaN
#
#       Data da publicação da compra sem licitação  \
# 280                                          NaN
# 8300                                         NaN
# 11632                                        NaN
# 13320                                        NaN
# 15770                                        NaN
# 16784                                        NaN
# 17197                                        NaN
# 19359                                        NaN
# 20033                                        NaN
# 20928                                        NaN
# 21948                                        NaN
# 22962                                        NaN
# 24012                                        NaN
#
#                                              Itens > uri
# 280    /compraSemLicitacao/id/item_slicitacao/1582230...
# 8300   /compraSemLicitacao/id/item_slicitacao/1582230...
# 11632  /compraSemLicitacao/id/item_slicitacao/1582230...
# 13320  /compraSemLicitacao/id/item_slicitacao/1582230...
# 15770  /compraSemLicitacao/id/item_slicitacao/1582230...
# 16784  /compraSemLicitacao/id/item_slicitacao/1582230...
# 17197  /compraSemLicitacao/id/item_slicitacao/1582230...
# 19359  /compraSemLicitacao/id/item_slicitacao/1582230...
# 20033  /compraSemLicitacao/id/item_slicitacao/1582230...
# 20928  /compraSemLicitacao/id/item_slicitacao/1582230...
# 21948  /compraSemLicitacao/id/item_slicitacao/1582230...
# 22962  /compraSemLicitacao/id/item_slicitacao/1582230...
# 24012  /compraSemLicitacao/id/item_slicitacao/1582230...

# %%
fnd = compras_2020.query("UASG == '158223: FACULDADE NACIONAL DE DIREITO DA UFRJ'")

# %%
fnd.shape
# Out:
# (13, 15)

# %% [markdown]
# Quando a coluna que queremos pesquisar possui espaços, precisamos usar \` dentro do `query` para sinalizar ao método que estamos falando de uma única coluna.

# %%
compras_2020.query("`Código da modalidade da compra` == '7: Inexigibilidade'")
# Out:
#                                                    Orgão  \
# 6                             52121: COMANDO DO EXERCITO
# 8                             52121: COMANDO DO EXERCITO
# 10     26420: INST.FED.DE EDUC.,CIENC. E TEC.FARROUPILHA
# 15         26405: INST.FED.DE EDUC.,CIENC.E TEC.DO CEARÁ
# 17     26420: INST.FED.DE EDUC.,CIENC. E TEC.FARROUPILHA
# ...                                                  ...
# 95999           26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96000           26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96001           26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96002           26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96003           26271: FUNDACAO UNIVERSIDADE DE BRASILIA
#
#                                                     UASG  \
# 6          160482: 1A. BRIGADA DE INFANTARIA DE SELVA/RR
# 8             160272: 21 GRUPO DE ARTILHARIA CAMPANHA/RJ
# 10     154628: INST.FED.DE EDUC.CIENC.E TEC.CÂMPUS JA...
# 15                       158965: IFCE - CAMPUS ITAPIPOCA
# 17     158127: INST.FEDERAL DE EDUC.,CIENC.E TEC.FARR...
# ...                                                  ...
# 95999    154040: FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA - FUB
# 96000    154040: FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA - FUB
# 96001    154040: FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA - FUB
# 96002    154040: FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA - FUB
# 96003    154040: FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA - FUB
#
#       Código da modalidade da compra  Descrição Lei  Número Inciso  \
# 6                 7: Inexigibilidade            NaN              0
# 8                 7: Inexigibilidade            NaN              1
# 10                7: Inexigibilidade            NaN              2
# 15                7: Inexigibilidade            NaN              2
# 17                7: Inexigibilidade            NaN              2
# ...                              ...            ...            ...
# 95999             7: Inexigibilidade            NaN              0
# 96000             7: Inexigibilidade            NaN              0
# 96001             7: Inexigibilidade            NaN              0
# 96002             7: Inexigibilidade            NaN              0
# 96003             7: Inexigibilidade            NaN              0
#
#          Número processo  Quantidade item Valor total da compra  \
# 6      64307003761202011              NaN          R$ 90,000.00
# 8      64555006775202057              NaN          R$ 13,574.00
# 10     26420000129/20200              NaN           R$ 1,200.00
# 15     23812000445202092              NaN             R$ 980.00
# 17     23243001385202027              NaN             R$ 600.00
# ...                  ...              ...                   ...
# 95999  23106099983202001              NaN             R$ 342.00
# 96000  23106099835202088              NaN             R$ 450.00
# 96001  23106099884202011              NaN             R$ 340.00
# 96002  23106099991202049              NaN           R$ 6,300.00
# 96003  23106099991202049              NaN             R$ 315.00
#
#        Número da compra                         Descrição objeto licitação  \
# 6                   NaN  Objeto: Fornecimento de água e esgoto para áre...
# 8                   NaN  Objeto: Contratação de serviço de instalação, ...
# 10                  NaN  Objeto: Contratação de Palestrante Sra. Isabel...
# 15                  NaN  Objeto: Pagamento de inscrição no curso de cap...
# 17                  NaN  Objeto: Inscrição no curso de  OJS 3: CONFIGUR...
# ...                 ...                                                ...
# 95999               NaN  Objeto: Despesa bancária com contratação cambi...
# 96000               NaN  Objeto: Pagamento de Inscrição em Evento.     ...
# 96001               NaN  Objeto: Pagamento de Inscrição em Evento.     ...
# 96002               NaN  Objeto: Publicação do artigo científico intitu...
# 96003               NaN  Objeto: Despesa bancária com contratação cambi...
#
#                                  Descrição justificativa  \
# 6      Justificativa: Destina-se ao serviço de fornec...
# 8      Justificativa: Art. 25º, Inciso I da Lei nº 8....
# 10     Justificativa: Para a contratação de serviços ...
# 15     Justificativa: Inciso II, do art. 25 da Lei nº...
# 17     Justificativa: Lei 8666/93                    ...
# ...                                                  ...
# 95999  Justificativa: Empresa de economia mista admin...
# 96000  Justificativa: Inexigibilidade de licitação, v...
# 96001  Justificativa: Inexigibilidade de licitação, v...
# 96002  Justificativa: Tratar de publicação de artigo ...
# 96003  Justificativa: Empresa de economia mista admin...
#
#       Data de reconhecimento da compra sem licitação  \
# 6                                         30/04/2020
# 8                                         29/10/2020
# 10                                        18/02/2020
# 15                                        19/11/2020
# 17                                        07/04/2020
# ...                                              ...
# 95999                                     23/11/2020
# 96000                                     16/10/2020
# 96001                                     15/10/2020
# 96002                                     21/10/2020
# 96003                                     21/10/2020
#
#       Data da ratificação da compra sem licitação  \
# 6                                      05/05/2020
# 8                                             NaN
# 10                                            NaN
# 15                                            NaN
# 17                                            NaN
# ...                                           ...
# 95999                                         NaN
# 96000                                         NaN
# 96001                                         NaN
# 96002                                         NaN
# 96003                                         NaN
#
#       Data da publicação da compra sem licitação  \
# 6                                     07/05/2020
# 8                                            NaN
# 10                                           NaN
# 15                                           NaN
# 17                                           NaN
# ...                                          ...
# 95999                                        NaN
# 96000                                        NaN
# 96001                                        NaN
# 96002                                        NaN
# 96003                                        NaN
#
#                                              Itens > uri
# 6      /compraSemLicitacao/id/item_slicitacao/1604820...
# 8      /compraSemLicitacao/id/item_slicitacao/1602720...
# 10     /compraSemLicitacao/id/item_slicitacao/1546280...
# 15     /compraSemLicitacao/id/item_slicitacao/1589650...
# 17     /compraSemLicitacao/id/item_slicitacao/1581270...
# ...                                                  ...
# 95999  /compraSemLicitacao/id/item_slicitacao/1540400...
# 96000  /compraSemLicitacao/id/item_slicitacao/1540400...
# 96001  /compraSemLicitacao/id/item_slicitacao/1540400...
# 96002  /compraSemLicitacao/id/item_slicitacao/1540400...
# 96003  /compraSemLicitacao/id/item_slicitacao/1540400...
#
# [12273 rows x 15 columns]

# %% [markdown]
# Categorias como Orgão e Código da modalidade da compra servem para classificar os dados.
#
# Assim, podemos fazer perguntas como: *quais são os órgãos que mais frequentemente fazem compras sem licitação e quais são as modalidades de compra mais frequentes*.
#
# Para responder essas perguntas, podemos usar o método `.value_counts()`.

# %%
compras_2020["Orgão"].value_counts()
# Out:
# 52121: COMANDO DO EXERCITO                            33760
# 52131: COMANDO DA MARINHA                              9741
# 26443: EMPRESA BRASILEIRA DE SERVIÇOS HOSPITALARES     3688
# 52111: COMANDO DA AERONAUTICA                          2432
# 25000: MINISTERIO DA ECONOMIA                          2128
#                                                       ...
# 38646: CONSELHO REG.DE ADMINISTRAÇÃO DE TOCANTINS         1
# 38599: CONSELHO REG. DE MEDICINA DO ESTADO DO TO          1
# 93120: ESTADO DO ACRE                                     1
# 38742: CONSELHO REGIONAL DE ENFERMAGEM DO ACRE            1
# 49901: FUNDO DA MARINHA MERCANTE                          1
# Name: Orgão, Length: 316, dtype: int64

# %%
compras_2020["Código da modalidade da compra"].value_counts()
# Out:
# 6: Dispensa           83732
# 7: Inexigibilidade    12273
# Name: Código da modalidade da compra, dtype: int64

# %% [markdown]
# ### <a id='toc2_3_6_'></a>[Criando novas colunas](#toc0_)
#
# Podemos adicionar colunas a um `DataFrame` usando a seguinte sintaxe:
#
# `nome_do_dataframe['nome_da_nova_coluna'] = novo_valor`
#
# Se `novo_valor` for uma constante, os dados vão ser replicados para todas as linhas do `DataFrame`:

# %%
compras_2020["Data de extração"] = "04/02/2021"
compras_2020.head()
# Out:
#                                                Orgão  \
# 0                      52111: COMANDO DA AERONAUTICA
# 1  29208: COMPANHIA DE PESQUISA DE RECURSOS MINERAIS
# 2                      25000: MINISTERIO DA ECONOMIA
# 3  22202: EMPRESA BRASILEIRA DE PESQUISA AGROPECU...
# 4         37202: INSTITUTO NACIONAL DO SEGURO SOCIAL
#
#                                                 UASG  \
# 0         120641: GRUPAMENTO DE APOIO DE PORTO VELHO
# 1  495500: COMPANHIA DE PESQUISA DE RECURSOS MINE...
# 2     170198: DELEGACIA DA REC.FEDERAL EM GOIANIA/GO
# 3                               135020: EMBRAPA/CTAA
# 4             511359: GERÊNCIA EXECUTIVA CAMPINAS/SP
#
#   Código da modalidade da compra  Descrição Lei  Número Inciso  \
# 0                    6: Dispensa            NaN              2
# 1                    6: Dispensa            NaN              2
# 2                    6: Dispensa            NaN              2
# 3                    6: Dispensa            NaN              4
# 4                    6: Dispensa            NaN              2
#
#      Número processo  Quantidade item Valor total da compra  Número da compra  \
# 0  67206014598202031              NaN             R$ 313.00               NaN
# 1  48048.000613/2020              NaN          R$ 20,716.00               NaN
# 2  10120759636201977              NaN          R$ 14,245.00               NaN
# 3  21152.000208/2020              NaN         R$ 137,104.00               NaN
# 4  35014040275202063              NaN           R$ 8,760.00               NaN
#
#                           Descrição objeto licitação  \
# 0  Objeto: Contratação do serviço de prestação de...
# 1  Objeto: Aquisição de dispenser para álcool gel...
# 2  Objeto: Contratação de serviços de confecção d...
# 3  Objeto: Contratação de Prestação de Serviços d...
# 4  Objeto: Contratação de Companhia de Seguros pa...
#
#                              Descrição justificativa  \
# 0  Justificativa: Despesa de pequeno vulto, confo...
# 1  Justificativa: Aquisição de produtos e/ou serv...
# 2  Justificativa: Pequeno valor.                 ...
# 3  Justificativa: Contratação temporária, em cará...
# 4  Justificativa: Procedimento simplificado e de ...
#
#   Data de reconhecimento da compra sem licitação  \
# 0                                     06/03/2020
# 1                                     29/05/2020
# 2                                     27/12/2019
# 3                                     27/02/2020
# 4                                     14/04/2020
#
#   Data da ratificação da compra sem licitação  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                  27/02/2020
# 4                                         NaN
#
#   Data da publicação da compra sem licitação  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                 28/02/2020
# 4                                        NaN
#
#                                          Itens > uri Data de extração
# 0  /compraSemLicitacao/id/item_slicitacao/1206410...       04/02/2021
# 1  /compraSemLicitacao/id/item_slicitacao/4955000...       04/02/2021
# 2  /compraSemLicitacao/id/item_slicitacao/1701980...       04/02/2021
# 3  /compraSemLicitacao/id/item_slicitacao/1350200...       04/02/2021
# 4  /compraSemLicitacao/id/item_slicitacao/5113590...       04/02/2021

# %%
compras_2020.tail()
# Out:
#                                           Orgão  \
# 96000  26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96001  26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96002  26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96003  26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96004                 52131: COMANDO DA MARINHA
#
#                                                   UASG  \
# 96000  154040: FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA - FUB
# 96001  154040: FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA - FUB
# 96002  154040: FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA - FUB
# 96003  154040: FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA - FUB
# 96004         773000: DIRETORIA DE FINANCAS DA MARINHA
#
#       Código da modalidade da compra  Descrição Lei  Número Inciso  \
# 96000             7: Inexigibilidade            NaN              0
# 96001             7: Inexigibilidade            NaN              0
# 96002             7: Inexigibilidade            NaN              0
# 96003             7: Inexigibilidade            NaN              0
# 96004                    6: Dispensa            NaN              2
#
#          Número processo  Quantidade item Valor total da compra  \
# 96000  23106099835202088              NaN             R$ 450.00
# 96001  23106099884202011              NaN             R$ 340.00
# 96002  23106099991202049              NaN           R$ 6,300.00
# 96003  23106099991202049              NaN             R$ 315.00
# 96004  99973/2020                     NaN              R$ 10.00
#
#        Número da compra                         Descrição objeto licitação  \
# 96000               NaN  Objeto: Pagamento de Inscrição em Evento.     ...
# 96001               NaN  Objeto: Pagamento de Inscrição em Evento.     ...
# 96002               NaN  Objeto: Publicação do artigo científico intitu...
# 96003               NaN  Objeto: Despesa bancária com contratação cambi...
# 96004               NaN  Objeto: Serviço de telefonia                  ...
#
#                                  Descrição justificativa  \
# 96000  Justificativa: Inexigibilidade de licitação, v...
# 96001  Justificativa: Inexigibilidade de licitação, v...
# 96002  Justificativa: Tratar de publicação de artigo ...
# 96003  Justificativa: Empresa de economia mista admin...
# 96004  Justificativa: Art. 24º, Inciso II da Lei nº 8...
#
#       Data de reconhecimento da compra sem licitação  \
# 96000                                     16/10/2020
# 96001                                     15/10/2020
# 96002                                     21/10/2020
# 96003                                     21/10/2020
# 96004                                     27/01/2020
#
#       Data da ratificação da compra sem licitação  \
# 96000                                         NaN
# 96001                                         NaN
# 96002                                         NaN
# 96003                                         NaN
# 96004                                         NaN
#
#       Data da publicação da compra sem licitação  \
# 96000                                        NaN
# 96001                                        NaN
# 96002                                        NaN
# 96003                                        NaN
# 96004                                        NaN
#
#                                              Itens > uri Data de extração
# 96000  /compraSemLicitacao/id/item_slicitacao/1540400...       04/02/2021
# 96001  /compraSemLicitacao/id/item_slicitacao/1540400...       04/02/2021
# 96002  /compraSemLicitacao/id/item_slicitacao/1540400...       04/02/2021
# 96003  /compraSemLicitacao/id/item_slicitacao/1540400...       04/02/2021
# 96004  /compraSemLicitacao/id/item_slicitacao/7730000...       04/02/2021

# %% [markdown]
# Se `novo_valor` for uma lista, ela precisa ter um número de elementos igual ao número de linhas do `DataFrame` (nesse caso, 96.005).

# %%
compras_2020["Número aleatório"] = [123454, 35345634]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 compras_2020["Número aleatório"] = [123454, 35345634]
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
#    4164     Add series to DataFrame in specified column.
#    4165
#    (...)
#    4170     ensure homogeneity.
#    4171     """
# -> 4172     value = self._sanitize_column(value)
#    4174     if (
#    4175         key in self.columns
#    4176         and value.ndim == 1
#    4177         and not is_extension_array_dtype(value)
#    4178     ):
#    4179         # broadcast across multiple columns if necessary
#    4180         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py:4912, in DataFrame._sanitize_column(self, value)
#    4909     return _reindex_for_setitem(Series(value), self.index)
#    4911 if is_list_like(value):
# -> 4912     com.require_length_match(value, self.index)
#    4913 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (2) does not match length of index (96005)

# %%
from random import randint

numeros_aleatorios = []

tamanho_df = compras_2020.shape[0]

# executamos abaixo a função que gera um número aleatório o número de vezes igual ao de linhas no dataframe
for i in range(tamanho_df):
    numeros_aleatorios.append(randint(0, 1000000))

# %%
compras_2020["Número aleatório"] = numeros_aleatorios

# %%
compras_2020.head()
# Out:
#                                                Orgão  \
# 0                      52111: COMANDO DA AERONAUTICA
# 1  29208: COMPANHIA DE PESQUISA DE RECURSOS MINERAIS
# 2                      25000: MINISTERIO DA ECONOMIA
# 3  22202: EMPRESA BRASILEIRA DE PESQUISA AGROPECU...
# 4         37202: INSTITUTO NACIONAL DO SEGURO SOCIAL
#
#                                                 UASG  \
# 0         120641: GRUPAMENTO DE APOIO DE PORTO VELHO
# 1  495500: COMPANHIA DE PESQUISA DE RECURSOS MINE...
# 2     170198: DELEGACIA DA REC.FEDERAL EM GOIANIA/GO
# 3                               135020: EMBRAPA/CTAA
# 4             511359: GERÊNCIA EXECUTIVA CAMPINAS/SP
#
#   Código da modalidade da compra  Descrição Lei  Número Inciso  \
# 0                    6: Dispensa            NaN              2
# 1                    6: Dispensa            NaN              2
# 2                    6: Dispensa            NaN              2
# 3                    6: Dispensa            NaN              4
# 4                    6: Dispensa            NaN              2
#
#      Número processo  Quantidade item Valor total da compra  Número da compra  \
# 0  67206014598202031              NaN             R$ 313.00               NaN
# 1  48048.000613/2020              NaN          R$ 20,716.00               NaN
# 2  10120759636201977              NaN          R$ 14,245.00               NaN
# 3  21152.000208/2020              NaN         R$ 137,104.00               NaN
# 4  35014040275202063              NaN           R$ 8,760.00               NaN
#
#                           Descrição objeto licitação  \
# 0  Objeto: Contratação do serviço de prestação de...
# 1  Objeto: Aquisição de dispenser para álcool gel...
# 2  Objeto: Contratação de serviços de confecção d...
# 3  Objeto: Contratação de Prestação de Serviços d...
# 4  Objeto: Contratação de Companhia de Seguros pa...
#
#                              Descrição justificativa  \
# 0  Justificativa: Despesa de pequeno vulto, confo...
# 1  Justificativa: Aquisição de produtos e/ou serv...
# 2  Justificativa: Pequeno valor.                 ...
# 3  Justificativa: Contratação temporária, em cará...
# 4  Justificativa: Procedimento simplificado e de ...
#
#   Data de reconhecimento da compra sem licitação  \
# 0                                     06/03/2020
# 1                                     29/05/2020
# 2                                     27/12/2019
# 3                                     27/02/2020
# 4                                     14/04/2020
#
#   Data da ratificação da compra sem licitação  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                  27/02/2020
# 4                                         NaN
#
#   Data da publicação da compra sem licitação  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                 28/02/2020
# 4                                        NaN
#
#                                          Itens > uri Data de extração  \
# 0  /compraSemLicitacao/id/item_slicitacao/1206410...       04/02/2021
# 1  /compraSemLicitacao/id/item_slicitacao/4955000...       04/02/2021
# 2  /compraSemLicitacao/id/item_slicitacao/1701980...       04/02/2021
# 3  /compraSemLicitacao/id/item_slicitacao/1350200...       04/02/2021
# 4  /compraSemLicitacao/id/item_slicitacao/5113590...       04/02/2021
#
#    Número aleatório
# 0            354369
# 1            521766
# 2             73168
# 3            181802
# 4            192258

# %% [markdown]
# Já que criamos uma coluna numérica, é interessante ver também que podemos usar operações normais usando essas colunas. Por exemplo:

# %%
compras_2020["Número aleatório"]/10
# Out:
# 0        35436.9
# 1        52176.6
# 2         7316.8
# 3        18180.2
# 4        19225.8
#           ...
# 96000    51897.8
# 96001    64429.2
# 96002    53854.6
# 96003    28332.8
# 96004    50959.7
# Name: Número aleatório, Length: 96005, dtype: float64

# %% [markdown]
# Podemos salvar o resultado da operação em uma nova coluna

# %%
compras_2020["Aleatório mais 10"] = compras_2020["Número aleatório"] + 10
compras_2020.head()
# Out:
#                                                Orgão  \
# 0                      52111: COMANDO DA AERONAUTICA
# 1  29208: COMPANHIA DE PESQUISA DE RECURSOS MINERAIS
# 2                      25000: MINISTERIO DA ECONOMIA
# 3  22202: EMPRESA BRASILEIRA DE PESQUISA AGROPECU...
# 4         37202: INSTITUTO NACIONAL DO SEGURO SOCIAL
#
#                                                 UASG  \
# 0         120641: GRUPAMENTO DE APOIO DE PORTO VELHO
# 1  495500: COMPANHIA DE PESQUISA DE RECURSOS MINE...
# 2     170198: DELEGACIA DA REC.FEDERAL EM GOIANIA/GO
# 3                               135020: EMBRAPA/CTAA
# 4             511359: GERÊNCIA EXECUTIVA CAMPINAS/SP
#
#   Código da modalidade da compra  Descrição Lei  Número Inciso  \
# 0                    6: Dispensa            NaN              2
# 1                    6: Dispensa            NaN              2
# 2                    6: Dispensa            NaN              2
# 3                    6: Dispensa            NaN              4
# 4                    6: Dispensa            NaN              2
#
#      Número processo  Quantidade item Valor total da compra  Número da compra  \
# 0  67206014598202031              NaN             R$ 313.00               NaN
# 1  48048.000613/2020              NaN          R$ 20,716.00               NaN
# 2  10120759636201977              NaN          R$ 14,245.00               NaN
# 3  21152.000208/2020              NaN         R$ 137,104.00               NaN
# 4  35014040275202063              NaN           R$ 8,760.00               NaN
#
#                           Descrição objeto licitação  \
# 0  Objeto: Contratação do serviço de prestação de...
# 1  Objeto: Aquisição de dispenser para álcool gel...
# 2  Objeto: Contratação de serviços de confecção d...
# 3  Objeto: Contratação de Prestação de Serviços d...
# 4  Objeto: Contratação de Companhia de Seguros pa...
#
#                              Descrição justificativa  \
# 0  Justificativa: Despesa de pequeno vulto, confo...
# 1  Justificativa: Aquisição de produtos e/ou serv...
# 2  Justificativa: Pequeno valor.                 ...
# 3  Justificativa: Contratação temporária, em cará...
# 4  Justificativa: Procedimento simplificado e de ...
#
#   Data de reconhecimento da compra sem licitação  \
# 0                                     06/03/2020
# 1                                     29/05/2020
# 2                                     27/12/2019
# 3                                     27/02/2020
# 4                                     14/04/2020
#
#   Data da ratificação da compra sem licitação  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                  27/02/2020
# 4                                         NaN
#
#   Data da publicação da compra sem licitação  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                 28/02/2020
# 4                                        NaN
#
#                                          Itens > uri Data de extração  \
# 0  /compraSemLicitacao/id/item_slicitacao/1206410...       04/02/2021
# 1  /compraSemLicitacao/id/item_slicitacao/4955000...       04/02/2021
# 2  /compraSemLicitacao/id/item_slicitacao/1701980...       04/02/2021
# 3  /compraSemLicitacao/id/item_slicitacao/1350200...       04/02/2021
# 4  /compraSemLicitacao/id/item_slicitacao/5113590...       04/02/2021
#
#    Número aleatório  Aleatório mais 10
# 0            354369             354379
# 1            521766             521776
# 2             73168              73178
# 3            181802             181812
# 4            192258             192268

# %% [markdown]
# ### <a id='toc2_3_7_'></a>[Excluindo colunas](#toc0_)
#
# Podemos excluir colunas usando o método `.drop()` e passando as colunas que queremos remover com o argumento `columns`.

# %%
compras_2020.drop(columns=["Data de extração", "Número aleatório", "Aleatório mais 10"], inplace=True)

compras_2020.head(3)
# Out:
#                                                Orgão  \
# 0                      52111: COMANDO DA AERONAUTICA
# 1  29208: COMPANHIA DE PESQUISA DE RECURSOS MINERAIS
# 2                      25000: MINISTERIO DA ECONOMIA
#
#                                                 UASG  \
# 0         120641: GRUPAMENTO DE APOIO DE PORTO VELHO
# 1  495500: COMPANHIA DE PESQUISA DE RECURSOS MINE...
# 2     170198: DELEGACIA DA REC.FEDERAL EM GOIANIA/GO
#
#   Código da modalidade da compra  Descrição Lei  Número Inciso  \
# 0                    6: Dispensa            NaN              2
# 1                    6: Dispensa            NaN              2
# 2                    6: Dispensa            NaN              2
#
#      Número processo  Quantidade item Valor total da compra  Número da compra  \
# 0  67206014598202031              NaN             R$ 313.00               NaN
# 1  48048.000613/2020              NaN          R$ 20,716.00               NaN
# 2  10120759636201977              NaN          R$ 14,245.00               NaN
#
#                           Descrição objeto licitação  \
# 0  Objeto: Contratação do serviço de prestação de...
# 1  Objeto: Aquisição de dispenser para álcool gel...
# 2  Objeto: Contratação de serviços de confecção d...
#
#                              Descrição justificativa  \
# 0  Justificativa: Despesa de pequeno vulto, confo...
# 1  Justificativa: Aquisição de produtos e/ou serv...
# 2  Justificativa: Pequeno valor.                 ...
#
#   Data de reconhecimento da compra sem licitação  \
# 0                                     06/03/2020
# 1                                     29/05/2020
# 2                                     27/12/2019
#
#   Data da ratificação da compra sem licitação  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
#
#   Data da publicação da compra sem licitação  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
#
#                                          Itens > uri
# 0  /compraSemLicitacao/id/item_slicitacao/1206410...
# 1  /compraSemLicitacao/id/item_slicitacao/4955000...
# 2  /compraSemLicitacao/id/item_slicitacao/1701980...

# %% [markdown]
# ### <a id='toc2_3_8_'></a>[Executando operações permanentes](#toc0_)
#
# Se você voltar à última célula de código, pode verificar que passamos o argumento `inplace` para o método `drop`.
#
# Esse argumento tem um significado especial de instruir que a alteração resultante deve alterar **permanentemente** a variável sobre a qual foi executada. Assim, essa operação não retorna nenhum resultado e se tentarmos salvá-lo em uma nova variável, semelhante ao que ocorre com listas se usarmos `append`.
#
# O argumento `inplace` é aceito por grande parte dos métodos que são executados sobre um dataframe, como o `query`, que vimos anteriormente.
#
# <b>CUIDADO:Ao executar uma operação inplace, a mudança é permanente. Assim, para voltar ao estado anterior é necessário recarregar os dados daquela variável como foi feito originalmente. No nosso exemplo, se deletarmos uma coluna seria necessário recarregar o arquivo original.
#
# Além disso, isso pode gerar erros em certos casos. Se tentarmos executar o drop novamente da célula anterior o pandas irá informar que as colunas não existem e não podem ser removidas. </b>

# %%
compras_2020["teste"] = 'a'

df_teste = compras_2020.drop(columns=["teste"], inplace=True)

print(df_teste)
# Out:
# None

# %%
compras_2020.drop(columns=["Data de extração", "Número aleatório", "Aleatório mais 10"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 compras_2020.drop(columns=["Data de extração", "Número aleatório", "Aleatório mais 10"], inplace=True)
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
#    5257     errors: IgnoreRaise = "raise",
#    5258 ) -> DataFrame | None:
#    5259     """
#    5260     Drop specified labels from rows or columns.
#    5261
#    (...)
#    5394             weight  1.0     0.8
#    5395     """
# -> 5396     return super().drop(
#    5397         labels=labels,
#    5398         axis=axis,
#    5399         index=index,
#    5400         columns=columns,
#    5401         level=level,
#    5402         inplace=inplace,
#    5403         errors=errors,
#    5404     )
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:6977, in Index.drop(self, labels, errors)
#    6975 if mask.any():
#    6976     if errors != "ignore":
# -> 6977         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6978     indexer = indexer[~mask]
#    6979 return self.delete(indexer)
#
# KeyError: "['Data de extração', 'Número aleatório', 'Aleatório mais 10'] not found in axis"

# %% [markdown]
# ## <a id='toc2_4_'></a>[Retornando ao caso: encontrando casos onde há compra de cloroquina](#toc0_)
#
# O que queremos fazer, no final das contas, é encontrar as compras envolvendo cloroquina. Ao contrário da busca pela UFRJ ou por um determinado código de modalidade de compra, as informações sobre a cloroquina não estão estruturadas da mesma forma. provavelmente, vamos encontrar menções à cloroquina na coluna que descreve o objeto da licitação. Mas a menção à cloroquina pode se dar em qualquer lugar dentro deste campo e de várias formas diferentes.
#
# Para encontrar o que estamos procurando, precisamos usar as habilidades adquiridas em programação para advogados.
#
# Sabemos, por exemplo, que podemos usar o operador `is in` com objetos do tipo `str` para saber se uma determinada substring está contida naquele objeto.
#
# A dúvida é: como fazer uso dessa operação no `pandas`? Existem algumas opções. A primeira dela envolve um `for loop`.

# %%
cloroquina_bin = []

for index, value in compras_2020["Descrição objeto licitação"].items(): # assim como com dicionários, precisamos adicionar esse método
    if type(value) == str and "cloroquina" in value.lower():
        cloroquina_bin.append(1)
    else:
        cloroquina_bin.append(0)
        
compras_2020["cloroquina_bin"] = cloroquina_bin

# %%
compras_2020.query("cloroquina_bin == 1")
# Out:
#                                                    Orgão  \
# 9280                              97320: ESTADO DE GOIAS
# 18939                         52121: COMANDO DO EXERCITO
# 22191                         52121: COMANDO DO EXERCITO
# 22448                         52121: COMANDO DO EXERCITO
# 26081                         52121: COMANDO DO EXERCITO
# 27071                         52121: COMANDO DO EXERCITO
# 27568                         52121: COMANDO DO EXERCITO
# 28847                         52121: COMANDO DO EXERCITO
# 35952                         52121: COMANDO DO EXERCITO
# 40557                         52121: COMANDO DO EXERCITO
# 45104  26443: EMPRESA BRASILEIRA DE SERVIÇOS HOSPITAL...
# 46257                         52121: COMANDO DO EXERCITO
# 48411  26443: EMPRESA BRASILEIRA DE SERVIÇOS HOSPITAL...
# 48534                       36201: FUNDACAO OSWALDO CRUZ
# 63495                              93420: ESTADO DO PARA
# 81612                         36000: MINISTERIO DA SAUDE
#
#                                                     UASG  \
# 9280            989631: PREFEITURA MUNICIPAL DE TURVANIA
# 18939  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 22191  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 22448  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 26081  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 27071  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 27568  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 28847  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 35952  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 40557  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 45104  155010: EMPRESA BRASILEIRA DE SERVIÇOS HOSPITA...
# 46257  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 48411      155021: HOSPITAL DAS CLÍNICAS DE MINAS GERAIS
# 48534  254447: MS-INSTITUTO FERNANDES FIGUEIRA/FIOCRU...
# 63495      927872: FUNDO MUNICIPAL DE SAÚDE DE BARCARENA
# 81612               250042: HOSPITAL GERAL DE BONSUCESSO
#
#       Código da modalidade da compra  Descrição Lei  Número Inciso  \
# 9280                     6: Dispensa            NaN              2
# 18939                    6: Dispensa            NaN              4
# 22191                    6: Dispensa            NaN              4
# 22448                    6: Dispensa            NaN              4
# 26081                    6: Dispensa            NaN              4
# 27071                    6: Dispensa            NaN              4
# 27568                    6: Dispensa            NaN              4
# 28847                    6: Dispensa            NaN              4
# 35952                    6: Dispensa            NaN              0
# 40557                    6: Dispensa            NaN              0
# 45104                    6: Dispensa            NaN              0
# 46257                    6: Dispensa            NaN              0
# 48411                    6: Dispensa            NaN              0
# 48534                    6: Dispensa            NaN              2
# 63495                    6: Dispensa            NaN              0
# 81612                    6: Dispensa            NaN              2
#
#          Número processo  Quantidade item Valor total da compra  \
# 9280   4006/2020                      NaN          R$ 10,740.00
# 18939  64614001085202060              NaN          R$ 35,136.00
# 22191  64614001085202060              NaN          R$ 35,136.00
# 22448  64614001085202060              NaN          R$ 30,744.00
# 26081  64614001104202058              NaN          R$ 34,648.00
# 27071  64614001104202058              NaN          R$ 34,648.00
# 27568  64614001104202058              NaN          R$ 31,720.00
# 28847  64614.001111/2020              NaN             R$ 680.00
# 35952  64614001499202099              NaN          R$ 11,494.00
# 40557  64614001810202008              NaN         R$ 652,000.00
# 45104  23523.013205/2020              NaN         R$ 788,315.00
# 46257  64614002114202019              NaN         R$ 652,000.00
# 48411  23537.008217/2020              NaN           R$ 1,740.00
# 48534  25384000040202077              NaN                   NaN
# 63495  7-107/2020                     NaN         R$ 170,000.00
# 81612  33374138660202025              NaN           R$ 7,196.00
#
#        Número da compra                         Descrição objeto licitação  \
# 9280                NaN  Objeto: Aquisição de Medicamentos em caráter d...
# 18939               NaN  Objeto: Aquisição de Cloroquina               ...
# 22191               NaN  Objeto: Aquisição de Cloroquina               ...
# 22448               NaN  Objeto: Aquisição de Cloroquina               ...
# 26081               NaN  Objeto: Aquisição de insumo para a produção de...
# 27071               NaN  Objeto: Aquisição de insumo para a produção de...
# 27568               NaN  Objeto: Aquisição de insumo para a produção de...
# 28847               NaN  Objeto: Alumínio Duro de Cloroquina.          ...
# 35952               NaN  Objeto: Aquisição de material para produção de...
# 40557               NaN  Objeto: Aquisição de insumo farmacêutico Ativo...
# 45104               NaN  Objeto: Aquisição de medicamentos, tipo: cisat...
# 46257               NaN  Objeto: Aquisição do insumo Cloroquina        ...
# 48411               NaN  Objeto: AQUISIÇÃO DE HIDROXICLOROQUINA, SULFAT...
# 48534               NaN  Objeto: Aquisição de Hidroxicloroquina.       ...
# 63495               NaN  Objeto: Contratação de empresa especializada p...
# 81612               NaN  Objeto: Metotrexato, 50mg/ml-inj. (f/a 10ml); ...
#
#                                  Descrição justificativa  \
# 9280   Justificativa: Aquisição de produtos e/ou serv...
# 18939  Justificativa: Aquisição de Material conf. Inc...
# 22191  Justificativa: Aquisição de Material conf. Inc...
# 22448  Justificativa: Aquisição de Material conf. Inc...
# 26081  Justificativa: Compra de caráter emergencial n...
# 27071  Justificativa: Compra de caráter emergencial n...
# 27568  Justificativa: Compra de caráter emergencial n...
# 28847  Justificativa: Aquisição de Insumos para produ...
# 35952  Justificativa: Utilizados no tratamento e prev...
# 40557  Justificativa: Compra de caráter emergencial d...
# 45104  Justificativa: Aquisição de medicamentos para ...
# 46257  Justificativa: Para produção de Cloroquina uti...
# 48411  Justificativa: Contratação destinada ao enfren...
# 48534  Justificativa: Aquisição de produtos e/ou serv...
# 63495  Justificativa: Contratação emergencial de medi...
# 81612  Justificativa: Aquisição de produtos e/ou serv...
#
#       Data de reconhecimento da compra sem licitação  \
# 9280                                      10/07/2020
# 18939                                     20/03/2020
# 22191                                     20/03/2020
# 22448                                     20/03/2020
# 26081                                     23/03/2020
# 27071                                     23/03/2020
# 27568                                     23/03/2020
# 28847                                     23/03/2020
# 35952                                     16/04/2020
# 40557                                     06/05/2020
# 45104                                     12/05/2020
# 46257                                     20/05/2020
# 48411                                     04/05/2020
# 48534                                     22/05/2020
# 63495                                     05/05/2020
# 81612                                     06/10/2020
#
#       Data da ratificação da compra sem licitação  \
# 9280                                          NaN
# 18939                                         NaN
# 22191                                         NaN
# 22448                                         NaN
# 26081                                         NaN
# 27071                                         NaN
# 27568                                         NaN
# 28847                                         NaN
# 35952                                         NaN
# 40557                                         NaN
# 45104                                  13/05/2020
# 46257                                         NaN
# 48411                                         NaN
# 48534                                         NaN
# 63495                                         NaN
# 81612                                         NaN
#
#       Data da publicação da compra sem licitação  \
# 9280                                         NaN
# 18939                                        NaN
# 22191                                        NaN
# 22448                                        NaN
# 26081                                        NaN
# 27071                                        NaN
# 27568                                        NaN
# 28847                                        NaN
# 35952                                        NaN
# 40557                                        NaN
# 45104                                 15/05/2020
# 46257                                        NaN
# 48411                                        NaN
# 48534                                        NaN
# 63495                                        NaN
# 81612                                        NaN
#
#                                              Itens > uri  cloroquina_bin
# 9280   /compraSemLicitacao/id/item_slicitacao/9896310...               1
# 18939  /compraSemLicitacao/id/item_slicitacao/1603280...               1
# 22191  /compraSemLicitacao/id/item_slicitacao/1603280...               1
# 22448  /compraSemLicitacao/id/item_slicitacao/1603280...               1
# 26081  /compraSemLicitacao/id/item_slicitacao/1603280...               1
# 27071  /compraSemLicitacao/id/item_slicitacao/1603280...               1
# 27568  /compraSemLicitacao/id/item_slicitacao/1603280...               1
# 28847  /compraSemLicitacao/id/item_slicitacao/1603280...               1
# 35952  /compraSemLicitacao/id/item_slicitacao/1603280...               1
# 40557  /compraSemLicitacao/id/item_slicitacao/1603280...               1
# 45104  /compraSemLicitacao/id/item_slicitacao/1550100...               1
# 46257  /compraSemLicitacao/id/item_slicitacao/1603280...               1
# 48411  /compraSemLicitacao/id/item_slicitacao/1550210...               1
# 48534  /compraSemLicitacao/id/item_slicitacao/2544470...               1
# 63495  /compraSemLicitacao/id/item_slicitacao/9278720...               1
# 81612  /compraSemLicitacao/id/item_slicitacao/2500420...               1

# %% [markdown]
# Outra forma de fazer a mesma coisa que usaremos ao longo do curso é utilizar operações "vetorizadas", que são aplicadas sobre toda a coluna. No caso, queremos fazer operações de `string`, assim devemos adicionar o indicador `.str` após a coluna acessada.
#
# Primeiro vamos converter toda a coluna para letras minúsculas, e então descobrir se ela contém a palavra cloroquina (veja que usamos `.str` novamente).

# %%
compras_2020["Descrição objeto licitação"].str.lower().str.contains("cloroquina")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 96000    False
# 96001    False
# 96002    False
# 96003    False
# 96004    False
# Name: Descrição objeto licitação, Length: 96005, dtype: object

# %% [markdown]
# Como comentamos no início do notebook, estamos subindo no ombro de gigantes e boa parte do que precisamos fazer para tratar dados já foi feito e disponibilizado de forma ainda mais simples. Assim, podemos simplificar essa operação e pedir que o método `contains` ignore a diferença de capitalização nas letras com o argumento `case=False`.
#
# Case é a expressão inglesa para se referir a capitalização.

# %%
compras_2020["cloroquina_bin"] = compras_2020["Descrição objeto licitação"].str.contains("cloroquina", case=False)
compras_2020.query("cloroquina_bin == True")
# Out:
#                                                    Orgão  \
# 9280                              97320: ESTADO DE GOIAS
# 18939                         52121: COMANDO DO EXERCITO
# 22191                         52121: COMANDO DO EXERCITO
# 22448                         52121: COMANDO DO EXERCITO
# 26081                         52121: COMANDO DO EXERCITO
# 27071                         52121: COMANDO DO EXERCITO
# 27568                         52121: COMANDO DO EXERCITO
# 28847                         52121: COMANDO DO EXERCITO
# 35952                         52121: COMANDO DO EXERCITO
# 40557                         52121: COMANDO DO EXERCITO
# 45104  26443: EMPRESA BRASILEIRA DE SERVIÇOS HOSPITAL...
# 46257                         52121: COMANDO DO EXERCITO
# 48411  26443: EMPRESA BRASILEIRA DE SERVIÇOS HOSPITAL...
# 48534                       36201: FUNDACAO OSWALDO CRUZ
# 63495                              93420: ESTADO DO PARA
# 81612                         36000: MINISTERIO DA SAUDE
#
#                                                     UASG  \
# 9280            989631: PREFEITURA MUNICIPAL DE TURVANIA
# 18939  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 22191  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 22448  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 26081  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 27071  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 27568  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 28847  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 35952  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 40557  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 45104  155010: EMPRESA BRASILEIRA DE SERVIÇOS HOSPITA...
# 46257  160328: LABORATORIO QUIMICO FARMACEUTICO DO EX...
# 48411      155021: HOSPITAL DAS CLÍNICAS DE MINAS GERAIS
# 48534  254447: MS-INSTITUTO FERNANDES FIGUEIRA/FIOCRU...
# 63495      927872: FUNDO MUNICIPAL DE SAÚDE DE BARCARENA
# 81612               250042: HOSPITAL GERAL DE BONSUCESSO
#
#       Código da modalidade da compra  Descrição Lei  Número Inciso  \
# 9280                     6: Dispensa            NaN              2
# 18939                    6: Dispensa            NaN              4
# 22191                    6: Dispensa            NaN              4
# 22448                    6: Dispensa            NaN              4
# 26081                    6: Dispensa            NaN              4
# 27071                    6: Dispensa            NaN              4
# 27568                    6: Dispensa            NaN              4
# 28847                    6: Dispensa            NaN              4
# 35952                    6: Dispensa            NaN              0
# 40557                    6: Dispensa            NaN              0
# 45104                    6: Dispensa            NaN              0
# 46257                    6: Dispensa            NaN              0
# 48411                    6: Dispensa            NaN              0
# 48534                    6: Dispensa            NaN              2
# 63495                    6: Dispensa            NaN              0
# 81612                    6: Dispensa            NaN              2
#
#          Número processo  Quantidade item Valor total da compra  \
# 9280   4006/2020                      NaN          R$ 10,740.00
# 18939  64614001085202060              NaN          R$ 35,136.00
# 22191  64614001085202060              NaN          R$ 35,136.00
# 22448  64614001085202060              NaN          R$ 30,744.00
# 26081  64614001104202058              NaN          R$ 34,648.00
# 27071  64614001104202058              NaN          R$ 34,648.00
# 27568  64614001104202058              NaN          R$ 31,720.00
# 28847  64614.001111/2020              NaN             R$ 680.00
# 35952  64614001499202099              NaN          R$ 11,494.00
# 40557  64614001810202008              NaN         R$ 652,000.00
# 45104  23523.013205/2020              NaN         R$ 788,315.00
# 46257  64614002114202019              NaN         R$ 652,000.00
# 48411  23537.008217/2020              NaN           R$ 1,740.00
# 48534  25384000040202077              NaN                   NaN
# 63495  7-107/2020                     NaN         R$ 170,000.00
# 81612  33374138660202025              NaN           R$ 7,196.00
#
#        Número da compra                         Descrição objeto licitação  \
# 9280                NaN  Objeto: Aquisição de Medicamentos em caráter d...
# 18939               NaN  Objeto: Aquisição de Cloroquina               ...
# 22191               NaN  Objeto: Aquisição de Cloroquina               ...
# 22448               NaN  Objeto: Aquisição de Cloroquina               ...
# 26081               NaN  Objeto: Aquisição de insumo para a produção de...
# 27071               NaN  Objeto: Aquisição de insumo para a produção de...
# 27568               NaN  Objeto: Aquisição de insumo para a produção de...
# 28847               NaN  Objeto: Alumínio Duro de Cloroquina.          ...
# 35952               NaN  Objeto: Aquisição de material para produção de...
# 40557               NaN  Objeto: Aquisição de insumo farmacêutico Ativo...
# 45104               NaN  Objeto: Aquisição de medicamentos, tipo: cisat...
# 46257               NaN  Objeto: Aquisição do insumo Cloroquina        ...
# 48411               NaN  Objeto: AQUISIÇÃO DE HIDROXICLOROQUINA, SULFAT...
# 48534               NaN  Objeto: Aquisição de Hidroxicloroquina.       ...
# 63495               NaN  Objeto: Contratação de empresa especializada p...
# 81612               NaN  Objeto: Metotrexato, 50mg/ml-inj. (f/a 10ml); ...
#
#                                  Descrição justificativa  \
# 9280   Justificativa: Aquisição de produtos e/ou serv...
# 18939  Justificativa: Aquisição de Material conf. Inc...
# 22191  Justificativa: Aquisição de Material conf. Inc...
# 22448  Justificativa: Aquisição de Material conf. Inc...
# 26081  Justificativa: Compra de caráter emergencial n...
# 27071  Justificativa: Compra de caráter emergencial n...
# 27568  Justificativa: Compra de caráter emergencial n...
# 28847  Justificativa: Aquisição de Insumos para produ...
# 35952  Justificativa: Utilizados no tratamento e prev...
# 40557  Justificativa: Compra de caráter emergencial d...
# 45104  Justificativa: Aquisição de medicamentos para ...
# 46257  Justificativa: Para produção de Cloroquina uti...
# 48411  Justificativa: Contratação destinada ao enfren...
# 48534  Justificativa: Aquisição de produtos e/ou serv...
# 63495  Justificativa: Contratação emergencial de medi...
# 81612  Justificativa: Aquisição de produtos e/ou serv...
#
#       Data de reconhecimento da compra sem licitação  \
# 9280                                      10/07/2020
# 18939                                     20/03/2020
# 22191                                     20/03/2020
# 22448                                     20/03/2020
# 26081                                     23/03/2020
# 27071                                     23/03/2020
# 27568                                     23/03/2020
# 28847                                     23/03/2020
# 35952                                     16/04/2020
# 40557                                     06/05/2020
# 45104                                     12/05/2020
# 46257                                     20/05/2020
# 48411                                     04/05/2020
# 48534                                     22/05/2020
# 63495                                     05/05/2020
# 81612                                     06/10/2020
#
#       Data da ratificação da compra sem licitação  \
# 9280                                          NaN
# 18939                                         NaN
# 22191                                         NaN
# 22448                                         NaN
# 26081                                         NaN
# 27071                                         NaN
# 27568                                         NaN
# 28847                                         NaN
# 35952                                         NaN
# 40557                                         NaN
# 45104                                  13/05/2020
# 46257                                         NaN
# 48411                                         NaN
# 48534                                         NaN
# 63495                                         NaN
# 81612                                         NaN
#
#       Data da publicação da compra sem licitação  \
# 9280                                         NaN
# 18939                                        NaN
# 22191                                        NaN
# 22448                                        NaN
# 26081                                        NaN
# 27071                                        NaN
# 27568                                        NaN
# 28847                                        NaN
# 35952                                        NaN
# 40557                                        NaN
# 45104                                 15/05/2020
# 46257                                        NaN
# 48411                                        NaN
# 48534                                        NaN
# 63495                                        NaN
# 81612                                        NaN
#
#                                              Itens > uri cloroquina_bin
# 9280   /compraSemLicitacao/id/item_slicitacao/9896310...           True
# 18939  /compraSemLicitacao/id/item_slicitacao/1603280...           True
# 22191  /compraSemLicitacao/id/item_slicitacao/1603280...           True
# 22448  /compraSemLicitacao/id/item_slicitacao/1603280...           True
# 26081  /compraSemLicitacao/id/item_slicitacao/1603280...           True
# 27071  /compraSemLicitacao/id/item_slicitacao/1603280...           True
# 27568  /compraSemLicitacao/id/item_slicitacao/1603280...           True
# 28847  /compraSemLicitacao/id/item_slicitacao/1603280...           True
# 35952  /compraSemLicitacao/id/item_slicitacao/1603280...           True
# 40557  /compraSemLicitacao/id/item_slicitacao/1603280...           True
# 45104  /compraSemLicitacao/id/item_slicitacao/1550100...           True
# 46257  /compraSemLicitacao/id/item_slicitacao/1603280...           True
# 48411  /compraSemLicitacao/id/item_slicitacao/1550210...           True
# 48534  /compraSemLicitacao/id/item_slicitacao/2544470...           True
# 63495  /compraSemLicitacao/id/item_slicitacao/9278720...           True
# 81612  /compraSemLicitacao/id/item_slicitacao/2500420...           True

# %% [markdown]
# ### <a id='toc2_4_1_'></a>[Tratando os dados](#toc0_)
#
# Já vimos que quando temos colunas numéricas, podemos fazer operações. Poderíamos, por exemplo, pedir a soma de todos os valores pagos em compras de cloroquina. Infelizmente, a coluna "Valor total da compra" não é numérica. Precisamos transformar essa coluna em numérica.

# %%
compras_2020
# Out:
#                                                    Orgão  \
# 0                          52111: COMANDO DA AERONAUTICA
# 1      29208: COMPANHIA DE PESQUISA DE RECURSOS MINERAIS
# 2                          25000: MINISTERIO DA ECONOMIA
# 3      22202: EMPRESA BRASILEIRA DE PESQUISA AGROPECU...
# 4             37202: INSTITUTO NACIONAL DO SEGURO SOCIAL
# ...                                                  ...
# 96000           26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96001           26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96002           26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96003           26271: FUNDACAO UNIVERSIDADE DE BRASILIA
# 96004                          52131: COMANDO DA MARINHA
#
#                                                     UASG  \
# 0             120641: GRUPAMENTO DE APOIO DE PORTO VELHO
# 1      495500: COMPANHIA DE PESQUISA DE RECURSOS MINE...
# 2         170198: DELEGACIA DA REC.FEDERAL EM GOIANIA/GO
# 3                                   135020: EMBRAPA/CTAA
# 4                 511359: GERÊNCIA EXECUTIVA CAMPINAS/SP
# ...                                                  ...
# 96000    154040: FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA - FUB
# 96001    154040: FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA - FUB
# 96002    154040: FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA - FUB
# 96003    154040: FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA - FUB
# 96004           773000: DIRETORIA DE FINANCAS DA MARINHA
#
#       Código da modalidade da compra  Descrição Lei  Número Inciso  \
# 0                        6: Dispensa            NaN              2
# 1                        6: Dispensa            NaN              2
# 2                        6: Dispensa            NaN              2
# 3                        6: Dispensa            NaN              4
# 4                        6: Dispensa            NaN              2
# ...                              ...            ...            ...
# 96000             7: Inexigibilidade            NaN              0
# 96001             7: Inexigibilidade            NaN              0
# 96002             7: Inexigibilidade            NaN              0
# 96003             7: Inexigibilidade            NaN              0
# 96004                    6: Dispensa            NaN              2
#
#          Número processo  Quantidade item Valor total da compra  \
# 0      67206014598202031              NaN             R$ 313.00
# 1      48048.000613/2020              NaN          R$ 20,716.00
# 2      10120759636201977              NaN          R$ 14,245.00
# 3      21152.000208/2020              NaN         R$ 137,104.00
# 4      35014040275202063              NaN           R$ 8,760.00
# ...                  ...              ...                   ...
# 96000  23106099835202088              NaN             R$ 450.00
# 96001  23106099884202011              NaN             R$ 340.00
# 96002  23106099991202049              NaN           R$ 6,300.00
# 96003  23106099991202049              NaN             R$ 315.00
# 96004  99973/2020                     NaN              R$ 10.00
#
#        Número da compra                         Descrição objeto licitação  \
# 0                   NaN  Objeto: Contratação do serviço de prestação de...
# 1                   NaN  Objeto: Aquisição de dispenser para álcool gel...
# 2                   NaN  Objeto: Contratação de serviços de confecção d...
# 3                   NaN  Objeto: Contratação de Prestação de Serviços d...
# 4                   NaN  Objeto: Contratação de Companhia de Seguros pa...
# ...                 ...                                                ...
# 96000               NaN  Objeto: Pagamento de Inscrição em Evento.     ...
# 96001               NaN  Objeto: Pagamento de Inscrição em Evento.     ...
# 96002               NaN  Objeto: Publicação do artigo científico intitu...
# 96003               NaN  Objeto: Despesa bancária com contratação cambi...
# 96004               NaN  Objeto: Serviço de telefonia                  ...
#
#                                  Descrição justificativa  \
# 0      Justificativa: Despesa de pequeno vulto, confo...
# 1      Justificativa: Aquisição de produtos e/ou serv...
# 2      Justificativa: Pequeno valor.                 ...
# 3      Justificativa: Contratação temporária, em cará...
# 4      Justificativa: Procedimento simplificado e de ...
# ...                                                  ...
# 96000  Justificativa: Inexigibilidade de licitação, v...
# 96001  Justificativa: Inexigibilidade de licitação, v...
# 96002  Justificativa: Tratar de publicação de artigo ...
# 96003  Justificativa: Empresa de economia mista admin...
# 96004  Justificativa: Art. 24º, Inciso II da Lei nº 8...
#
#       Data de reconhecimento da compra sem licitação  \
# 0                                         06/03/2020
# 1                                         29/05/2020
# 2                                         27/12/2019
# 3                                         27/02/2020
# 4                                         14/04/2020
# ...                                              ...
# 96000                                     16/10/2020
# 96001                                     15/10/2020
# 96002                                     21/10/2020
# 96003                                     21/10/2020
# 96004                                     27/01/2020
#
#       Data da ratificação da compra sem licitação  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                      27/02/2020
# 4                                             NaN
# ...                                           ...
# 96000                                         NaN
# 96001                                         NaN
# 96002                                         NaN
# 96003                                         NaN
# 96004                                         NaN
#
#       Data da publicação da compra sem licitação  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                     28/02/2020
# 4                                            NaN
# ...                                          ...
# 96000                                        NaN
# 96001                                        NaN
# 96002                                        NaN
# 96003                                        NaN
# 96004                                        NaN
#
#                                              Itens > uri cloroquina_bin
# 0      /compraSemLicitacao/id/item_slicitacao/1206410...          False
# 1      /compraSemLicitacao/id/item_slicitacao/4955000...          False
# 2      /compraSemLicitacao/id/item_slicitacao/1701980...          False
# 3      /compraSemLicitacao/id/item_slicitacao/1350200...          False
# 4      /compraSemLicitacao/id/item_slicitacao/5113590...          False
# ...                                                  ...            ...
# 96000  /compraSemLicitacao/id/item_slicitacao/1540400...          False
# 96001  /compraSemLicitacao/id/item_slicitacao/1540400...          False
# 96002  /compraSemLicitacao/id/item_slicitacao/1540400...          False
# 96003  /compraSemLicitacao/id/item_slicitacao/1540400...          False
# 96004  /compraSemLicitacao/id/item_slicitacao/7730000...          False
#
# [96005 rows x 16 columns]

# %% [markdown]
# Para que os valores possam ser interpretados adequadamente como numéricos precisamos realizar 2 alterações:
#
# 1. Remover o R$ que antecede o valor de cada célula (sabemos pelo nome da coluna que se trata de um valor monetário).
# 2. Remover a vírgula que é utilizada como separador de milhares na tabela.
#
# Novamente uma primeira opção é usar os instrumentos apresentados em Programação para Advogados, a partir de um for loop:

# %%
#opção 1
valor_em_numero = []

for index, value in compras_2020["Valor total da compra"].items():
    if type(value) == str: # impedir que o código abaixo rode quando a célula está vazia
        valor_em_numero.append(float(value.replace("R$ ", "").replace(",", "")))
    else:
        valor_em_numero.append(value)
        
compras_2020["valor_numerico"] = valor_em_numero

# %% [markdown]
# Ou podemos simplificar realizando a operação diretamente sobre a coluna, sem a necessidade de um for loop.

# %%
#opção 2
compras_2020["valor_numerico"] = compras_2020["Valor total da compra"].str.replace("R$ ", "", regex=False).str.replace(",", "", regex=False).astype(float)

# ou ainda simplificando com uma única regex
compras_2020["valor_numerico"] = compras_2020["Valor total da compra"].str.replace("R\$ |,", "", regex=True).astype(float)

# %% [markdown]
# Agora podemos somar usando o método `sum`!

# %%
compras_2020["valor_numerico"].sum()
# Out:
# 21618270804.0

# %%
compras_2020.query("cloroquina_bin == 1")["valor_numerico"].sum()
# Out:
# 2496197.0

# %% [markdown]
# Poderíamos também facilmente acessar a média com o método que possui o nome da operação em inglês: `mean`

# %%
compras_2020.query("cloroquina_bin == 1")["valor_numerico"].mean()
# Out:
# 166413.13333333333

# %% [markdown]
# Podemos calcular quanto do total sem licitação os gastos com cloroquina representam.

# %%
# Multiplicamos por 100 para ter o resultado em porcentagem
(compras_2020.query("cloroquina_bin == True")["valor_numerico"].sum() / compras_2020["valor_numerico"].sum()) * 100
# Out:
# 0.011546700578559374

# %% [markdown]
# ### <a id='toc2_4_2_'></a>[Conclusão](#toc0_)
#
# Os gastos com cloroquina foram elevados em termos absolutos, mas modestos em termos relativos.
#
# #### Rodada bônus: guloseimas

# %%
compras_2020["leite_condensado_bin"] = compras_2020["Descrição objeto licitação"].str.contains("leite condensado", case=False)

# %%
compras_2020.query("leite_condensado_bin == True")
# Out:
#                            Orgão                              UASG  \
# 80910  52131: COMANDO DA MARINHA  782801: BASE NAVAL DE ARATU - BA
#
#       Código da modalidade da compra  Descrição Lei  Número Inciso  \
# 80910                    6: Dispensa            NaN              2
#
#          Número processo  Quantidade item Valor total da compra  \
# 80910  256                            NaN             R$ 450.00
#
#        Número da compra                         Descrição objeto licitação  \
# 80910               NaN  Objeto: Leite condensado e bombom serenata de ...
#
#                                  Descrição justificativa  \
# 80910  Justificativa: Aquisição em função do valor.  ...
#
#       Data de reconhecimento da compra sem licitação  \
# 80910                                     18/11/2020
#
#       Data da ratificação da compra sem licitação  \
# 80910                                         NaN
#
#       Data da publicação da compra sem licitação  \
# 80910                                        NaN
#
#                                              Itens > uri cloroquina_bin  \
# 80910  /compraSemLicitacao/id/item_slicitacao/7828010...          False
#
#        valor_numerico leite_condensado_bin
# 80910           450.0                 True

# %% [markdown]
# #### Rodada bônus 2: ivermectina

# %%
compras_2020["ivermectina_bin"] = compras_2020["Descrição objeto licitação"].str.contains("ivermectina", case=False)

# %%
compras_2020.query("ivermectina_bin == True")
# Out:
#                                                    Orgão  \
# 9280                              97320: ESTADO DE GOIAS
# 31275                30907: FUNDO PENITENCIARIO NACIONAL
# 32849                         52121: COMANDO DO EXERCITO
# 37306                          52131: COMANDO DA MARINHA
# 63977                              93420: ESTADO DO PARA
# 66893                      52111: COMANDO DA AERONAUTICA
# 78284  26443: EMPRESA BRASILEIRA DE SERVIÇOS HOSPITAL...
# 79013                         52121: COMANDO DO EXERCITO
#
#                                                     UASG  \
# 9280            989631: PREFEITURA MUNICIPAL DE TURVANIA
# 31275          200604: PENITENCIÁRIA FEDERAL EM BRASILIA
# 32849  160191: CENTRO PREPARACAO OFICIAIS DA RESERVA/...
# 37306                 782700: HOSPITAL NAVAL_DE SALVADOR
# 63977      927872: FUNDO MUNICIPAL DE SAÚDE DE BARCARENA
# 66893           120195: CENTRO DE AQUISIÇÕES ESPECIFICAS
# 78284  155011: HOSPITAL DE CLINICAS DO TRIANGULO MINEIRO
# 79013         160470: 12 GRUPO DE ARTILHARIA DE CAMPANHA
#
#       Código da modalidade da compra  Descrição Lei  Número Inciso  \
# 9280                     6: Dispensa            NaN              2
# 31275                    6: Dispensa            NaN              2
# 32849                    6: Dispensa            NaN              2
# 37306                    6: Dispensa            NaN              0
# 63977                    6: Dispensa            NaN              0
# 66893                    6: Dispensa            NaN              2
# 78284                    6: Dispensa            NaN              0
# 79013                    6: Dispensa            NaN              2
#
#          Número processo  Quantidade item Valor total da compra  \
# 9280   4006/2020                      NaN          R$ 10,740.00
# 31275  08016016505202081              NaN           R$ 1,200.00
# 32849  64215004500202030              NaN           R$ 3,114.00
# 37306  63607002489202051              NaN          R$ 20,000.00
# 63977  7-110/2020                     NaN         R$ 147,000.00
# 66893  67106001818202094              NaN           R$ 1,360.00
# 78284  23521010146202031              NaN           R$ 3,490.00
# 79013  64547013695202057              NaN           R$ 1,624.00
#
#        Número da compra                         Descrição objeto licitação  \
# 9280                NaN  Objeto: Aquisição de Medicamentos em caráter d...
# 31275               NaN  Objeto: Aquisição de medicamentos (Azitromicin...
# 32849               NaN  Objeto: Aquisição de insumos de saúde para ate...
# 37306               NaN  Objeto: Aquisição de ivermectina 6 mg e azitro...
# 63977               NaN  Objeto: Contratação de empresa especializada p...
# 66893               NaN  Objeto: Aquisição emergencial de IVERMECTINA C...
# 78284               NaN  Objeto: Aquisição do medicamento Ivermectina 6...
# 79013               NaN  Objeto: Aquisição de medicamento, Ivermectina....
#
#                                  Descrição justificativa  \
# 9280   Justificativa: Aquisição de produtos e/ou serv...
# 31275  Justificativa: Aquisição de produtos e/ou serv...
# 32849  Justificativa: Aquisição de produtos e/ou serv...
# 37306  Justificativa: Ações para o enfrentamento da e...
# 63977  Justificativa: Aquisição emergencial de medica...
# 66893  Justificativa: Aquisição de produtos e/ou serv...
# 78284  Justificativa: O item se trata de medicamento ...
# 79013  Justificativa: Aquisição de produtos e/ou serv...
#
#       Data de reconhecimento da compra sem licitação  \
# 9280                                      10/07/2020
# 31275                                     10/09/2020
# 32849                                     01/07/2020
# 37306                                     21/07/2020
# 63977                                     12/05/2020
# 66893                                     28/05/2020
# 78284                                     30/07/2020
# 79013                                     13/10/2020
#
#       Data da ratificação da compra sem licitação  \
# 9280                                          NaN
# 31275                                         NaN
# 32849                                         NaN
# 37306                                         NaN
# 63977                                         NaN
# 66893                                         NaN
# 78284                                         NaN
# 79013                                         NaN
#
#       Data da publicação da compra sem licitação  \
# 9280                                         NaN
# 31275                                        NaN
# 32849                                        NaN
# 37306                                        NaN
# 63977                                        NaN
# 66893                                        NaN
# 78284                                        NaN
# 79013                                        NaN
#
#                                              Itens > uri cloroquina_bin  \
# 9280   /compraSemLicitacao/id/item_slicitacao/9896310...           True
# 31275  /compraSemLicitacao/id/item_slicitacao/2006040...          False
# 32849  /compraSemLicitacao/id/item_slicitacao/1601910...          False
# 37306  /compraSemLicitacao/id/item_slicitacao/7827000...          False
# 63977  /compraSemLicitacao/id/item_slicitacao/9278720...          False
# 66893  /compraSemLicitacao/id/item_slicitacao/1201950...          False
# 78284  /compraSemLicitacao/id/item_slicitacao/1550110...          False
# 79013  /compraSemLicitacao/id/item_slicitacao/1604700...          False
#
#        valor_numerico leite_condensado_bin ivermectina_bin
# 9280          10740.0                False            True
# 31275          1200.0                False            True
# 32849          3114.0                False            True
# 37306         20000.0                False            True
# 63977        147000.0                False            True
# 66893          1360.0                False            True
# 78284          3490.0                False            True
# 79013          1624.0                False            True

# %%
compras_2020.query("ivermectina_bin == True").valor_numerico.sum()
# Out:
# 188528.0
